# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <h2 style="color:#0000FF;">其實我們不一定要爬蟲</h2>
#
# 我們要注意<b style="color:red;">我們想做的事</b>, 不要迷失在爬蟲技巧中！

# %% [markdown]
# ## MLB 資料
#     !pip installpybaseball

# %% [markdown]
# ## 'requests' + 'BeautifulSoup'

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.marieclaire.com.tw/love-sex"

# %%
resp = requests.get(url)

# %%
print(resp.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant">
# <head>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=0"/>
# <title>LOVE & SEX | Marie Claire 美麗佳人</title>
# <meta name="title" content="LOVE & SEX | Marie Claire 美麗佳人"/>
# <meta name="keywords" content="兩性,愛情,性愛"/>
# <meta name="news_keywords" itemprop="keywords" content="兩性,愛情,性愛"/>
# <meta name="description" content="兩性關係,星座運勢，陪伴你一起度過生命中的起起伏伏。"/>
# <link rel="preconnect" href="https://stats.g.doubleclick.net">
# <link rel="preconnect" href="https://www.google.com.tw">
# <link rel="preconnect" href="https://www.google.com">
# <link rel="preconnect" href="https://www.google-analytics.com">
# <link rel="preconnect" href="https://fonts.gstatic.com">
# <link rel="preconnect" href="https://tpc.googlesyndication.com">
# <link rel="preconnect" href="https://pixel.adsafeprotected.com">
# <link rel="preconnect" href="https://www.googletagservices.com"/>
# <link rel="preconnect" href="https://securepubads.g.doubleclick.net"/>
# <link rel="preload" as="style" href="https://fonts.googleapis.com/css?family=Frank+Ruhl+Libre:300,500,700|Noto+Sans+TC&display=swap">
# <link rel="preload" as="script" href="https://i.marieclaire.com.tw/assets/www/js/embed/1.4.63/public/mc.min.js">
# <link rel="preload" as="script" href="https://www.googletagservices.com/tag/js/gpt.js">
# <link rel="preload" as="script" href="https://i.marieclaire.com.tw/assets/www/js/public/93C6-758D-51B5-4D3F/ias_pet.js">
# <meta property="fb:pages" content="161789327743" />
# <meta property="og:type" content="website" />
# <meta property="og:title" content="Marie Claire 美麗佳人 - 流行時尚, 彩妝美容, 名人明星, 風格生活"/>
# <meta property="og:site_name" content="Marie Claire 美麗佳人" />
# <meta property="og:description" content="兩性關係,星座運勢，陪伴你一起度過生命中的起起伏伏。"/>
# <meta property="og:url" content="https://www.marieclaire.com.tw/love-sex" />
# <meta property="og:locale" content="zh_TW" />
# <link rel="shortcut icon" href="https://www.marieclaire.com.tw/favicon.ico" />
# <meta http-equiv="content-language" content="zh-Hant-TW" />
# <meta property="article:publisher" content="https://www.facebook.com/marieclaire.tw/"/>
# <meta property="fb:app_id" content="1931671150490548" />
# <meta name="robots" content="INDEX,FOLLOW">
# <meta name="google-site-verification" content="SEKw3oKyr7s_qRIb7Sw5Rs2YlDqN9re_DHVvshlFsCw" />
# <meta name="msvalidate.01" content="9EDDA5AD89E07F6D078D391E26B8E7EB" />
# <link rel="canonical" href="https://www.marieclaire.com.tw/love-sex">
# <script>
# var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "14383407" });
# (function() {
# var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# el.parentNode.insertBefore(s, el);
# })();
# </script>
# <script async='async' src='https://i.marieclaire.com.tw/assets/www/js/public/93C6-758D-51B5-4D3F/ias_pet.js'></script>
# <script async='async' src='https://www.googletagservices.com/tag/js/gpt.js'></script>
# <script>
# window.oneadCategory = "";
# window.mc_category = "";
#
# var dfp_adv_data = {};
# var dfp_adv_code = {"pc_supersky":{"note":"\u8d85\u7d1a\u5927\u6a6b\u5e45","wh":"[[1920, 450], [1920, 300], [970, 250]]","size_mappin":"pc","wh_set":[1920,450],"class_name":"adSky dfp_imp","refresh":true,"audience":false,"id_name":"pc_lovesex_supersky","slot_name":"\/32376598\/pc_lovesex_supersky"},"pc_skin":{"note":"\u9996\u9801\u8b8a\u5929\u7d44\u5408","wh":"[1920, 1200]","size_mappin":"pc","wh_set":[1920,1200],"class_name":"adSkin dfp_imp","refresh":true,"audience":false,"id_name":"pc_lovesex_skin","slot_name":"\/32376598\/pc_lovesex_skin"},"pc_billboard1a":{"note":"\u770b\u7248\u5ee3\u544a A","wh":"[[970, 90], [970, 250], [728, 90]]","size_mappin":"pc","wh_set":[970,90],"class_name":"adBillboard dfp_imp","refresh":true,"audience":false,"id_name":"pc_lovesex_billboard1a","slot_name":"\/32376598\/pc_lovesex_billboard1a"},"pc_billboard2b":{"note":"\u770b\u7248\u5ee3\u544a B","wh":"[[970, 90], [970, 250], [728, 90]]","size_mappin":"pc","wh_set":[970,90],"class_name":"adBillboard dfp_imp","refresh":true,"audience":false,"id_name":"pc_lovesex_billboard2b","slot_name":"\/32376598\/pc_lovesex_billboard2b"}};
#
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
#
# googletag.cmd.push(function() {
#
# <!-- 超級大橫幅 -->
# dfp_adv_data['pc_lovesex_supersky'] = googletag.defineSlot('/32376598/pc_lovesex_supersky', [[1920, 450], [1920, 300], [970, 250]], 'pc_lovesex_supersky').addService(googletag.pubads());
# <!-- 首頁變天組合 -->
# dfp_adv_data['pc_lovesex_skin'] = googletag.defineSlot('/32376598/pc_lovesex_skin', [1920, 1200], 'pc_lovesex_skin').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().collapseEmptyDivs();
#     googletag.enableServices();
# });
# var dfp_adv_list = [{"page":1,"name":"pc_supersky","setting":{"note":"\u8d85\u7d1a\u5927\u6a6b\u5e45","wh":"[[1920, 450], [1920, 300], [970, 250]]","size_mappin":"pc","wh_set":[1920,450],"class_name":"adSky dfp_imp","refresh":true,"audience":false,"id_name":"pc_lovesex_supersky","slot_name":"\/32376598\/pc_lovesex_supersky"},"id_name":"pc_lovesex_supersky"},{"page":1,"name":"pc_skin","setting":{"note":"\u9996\u9801\u8b8a\u5929\u7d44\u5408","wh":"[1920, 1200]","size_mappin":"pc","wh_set":[1920,1200],"class_name":"adSkin dfp_imp","refresh":true,"audience":false,"id_name":"pc_lovesex_skin","slot_name":"\/32376598\/pc_lovesex_skin"},"id_name":"pc_lovesex_skin"}];
# function requestAds()
# {
#     googletag.cmd.push(function() {
# <!--pc_supersky-->
# googletag.display('pc_lovesex_supersky');
#     <!--pc_skin-->
# googletag.display('pc_lovesex_skin');
#         });
# }
# var iasDataHandler, __iasPET = __iasPET || {};
# __iasPET.queue = __iasPET.queue || [];
# __iasPET.pubId = '928912';
#
# var IASPET_TIMEOUT = 2000;
# var __iasPETTimeoutRequestAds = setTimeout(requestAds, IASPET_TIMEOUT);
#
# var iasDataHandler = function(adSlotData) {
#     clearTimeout(__iasPETTimeoutRequestAds);
#     __iasPET.setTargetingForGPT();
#     requestAds();
# };
#
# googletag.cmd.push(function() {
#     var gptSlots = googletag.pubads().getSlots();
#
#     var iasPETSlots = [];
#     for (var i = 0; i < gptSlots.length; i++) {
#         var sizes = gptSlots[i].getSizes().map(function(size)
#         {if (size.getWidth && size.getHeight)
#             return [size.getWidth(), size.getHeight()];
#         else
#             return [1, 1];
#         });
#
#         iasPETSlots.push({
#         adSlotId: gptSlots[i].getSlotElementId(),
#
#         size: [[0, 0], [375, 350], [300, 250], [420, 180], [336, 280], [414, 812], [320, 480], [768, 200], [1920, 450], [1920, 300], [1920, 1200],[970, 90], [970, 250], [728, 90],[300, 600]],
#         adUnitPath: gptSlots[i].getAdUnitPath()
#         });
#     }
#     __iasPET.queue.push({
#         adSlots: iasPETSlots,
#         dataHandler: iasDataHandler
#     });
# });
# </script>
# <script type="text/javascript">
# _atrk_opts = { atrk_acct:"GLBoh1aMQV00y/", domain:"marieclaire.com.tw",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
# </script>
# <style>
# .slick-slider{position:relative;display:block;box-sizing:border-box;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-touch-callout:none;-khtml-user-select:none;-ms-touch-action:pan-y;touch-action:pan-y;-webkit-tap-highlight-color:transparent}.slick-list{position:relative;display:block;overflow:hidden;margin:0;padding:0}.slick-list:focus{outline:0}.slick-list.dragging{cursor:pointer;cursor:hand}.slick-slider .slick-list,.slick-slider .slick-track{-webkit-transform:translate3d(0,0,0);-moz-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);-o-transform:translate3d(0,0,0);transform:translate3d(0,0,0)}.slick-track{position:relative;top:0;left:0;display:block;margin-left:auto;margin-right:auto}.slick-track:after,.slick-track:before{display:table;content:''}.slick-track:after{clear:both}.slick-loading .slick-track{visibility:hidden}.slick-slide{display:none;float:left;height:100%;min-height:1px}[dir=rtl] .slick-slide{float:right}.slick-slide img{display:block}.slick-slide.slick-loading img{display:none}.slick-slide.dragging img{pointer-events:none}.slick-initialized .slick-slide{display:block}.slick-loading .slick-slide{visibility:hidden}.slick-vertical .slick-slide{display:block;height:auto;border:1px solid transparent}.slick-arrow.slick-hidden{display:none}.adSky>div[id^=google_ads_iframe]>iframe{width:100vw;margin-top:37px}.adSkin{position:absolute;overflow:hidden;left:50%;margin-left:-960px;z-index:-1;-webkit-box-sizing:border-box;box-sizing:border-box}.adUnderlay{position:relative;border-bottom:20px solid #f5f5f5}.adUnderlay::before{content:'廣告 - 內文未完請往下捲動';position:absolute;top:-1px;font-size:12px;line-height:20px;color:#999;background-color:#f5f5f5;width:100%;height:20px;text-align:center;z-index:1}.adTop{text-align:center;background-color:#f5f5f5}.adTop>div[id^=google_ads_iframe]{width:100vw;position:absolute;top:0;left:0}.adTop>div[id^=google_ads_iframe]>iframe{width:100%}.adTop .top_box{position:relative}.adTop .bottom_box{position:relative}.adTop .bottom_box>a{display:block}.adTop .img_box{position:relative;text-align:center}.adTop .img_box>a{width:100%}.adTop .bottom_img{width:100%}.adTop .video_box{position:relative}.adTop .video_box>a{display:block}.adTop #video01{width:100%}.controls{width:100%;height:30px;position:absolute;left:0;top:-30px;pointer-events:none}.controls .play_btn,.controls .sound{position:absolute;pointer-events:auto;width:20px;bottom:5px;cursor:pointer;z-index:99}.controls .sound{right:10px}.controls .play_btn{left:10px}.close_btn{position:absolute;width:30px;height:30px;top:0;right:0;background:#000;z-index:99}.close_btn::after,.close_btn::before{content:'';display:block;width:80%;height:3px;background:#fff;position:absolute;top:50%;left:50%}.close_btn::after{-webkit-transform:translate(-50%,-50%) rotate(45deg);transform:translate(-50%,-50%) rotate(45deg)}.close_btn::before{-webkit-transform:translate(-50%,-50%) rotate(-45deg);transform:translate(-50%,-50%) rotate(-45deg)}.adBillboard{background-color:#f5f5f5;padding:30px 0;position:relative;text-align:center;margin-top:50px;margin-bottom:30px}.adBillboard::before{content:'廣告 - 內文未完請往下捲動';position:absolute;top:6px;left:0;font-size:12px;color:#999;width:100%;text-align:center}.adMpu{background-color:#f5f5f5;padding:30px 0;position:relative;text-align:center}.adMpu::before{content:'廣告 - 內文未完請往下捲動';position:absolute;top:6px;left:0;font-size:12px;color:#999;width:100%;text-align:center}.adInnerMpu{background-color:#f5f5f5;padding:30px 0;position:relative;text-align:center}.adInnerMpu::before{content:'廣告 - 內文未完請往下捲動';position:absolute;top:6px;left:0;font-size:12px;color:#999;width:100%;text-align:center}.adGallery{background-color:#f5f5f5;padding:30px 0;position:relative;text-align:center}.adGallery::before{content:'廣告 - 內文未完請往下捲動';position:absolute;top:6px;left:0;font-size:12px;color:#999;width:100%;text-align:center}.adOpening>div[id^=google_ads_iframe]{position:absolute;width:1px;height:1px}.adOpen ...
# </style><script>
# var base_url = {"shop":"shop.marieclaire.com.tw\/","www":"www.marieclaire.com.tw\/","mc":"mc.marieclaire.com.tw\/","beauty-school":"beauty-school.marieclaire.com.tw\/","cdn":"i.marieclaire.com.tw\/","website_name":"Marie Claire \u7f8e\u9e97\u4f73\u4eba - \u6d41\u884c\u6642\u5c1a, \u5f69\u599d\u7f8e\u5bb9, \u540d\u4eba\u660e\u661f, \u98a8\u683c\u751f\u6d3b","js_hash_key":"1.4.63","host":"www","month":"12","year":"2019","type":"channel","mobile_open":"pc","g_a_u":"645d3fc7960ac5879840c776c34e6890","ish":"14ad90a39c89fd1a5c7e6c66c28a24cb","isc":"645d3fc7960ac5879840c776c34e6890","short_title":"Marie Claire \u7f8e\u9e97\u4f73\u4eba","audience":false,"aud_serial":"","aud_count":0,"token":"HPkdJ21S47lcpnZx"};
# </script>
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-3069360-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-3069360-1', {
#     'linker': {'accept_incoming': true},
#     'use_amp_client_id': true
# });
# gtag('config', 'UA-3069360-96', {
#     'linker': {'accept_incoming': true},
#     'custom_map': {'dimension1': 'user_id'},
#     'use_amp_client_id': true
# });
#
# gtag('event', 'user', {'user_id': base_url.g_a_u, 'nonInteraction':true});
#
# </script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     dataLayer.push({'user_id': base_url.g_a_u});
# </script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-M5V6KWS');</script>
# </head>
# <body>
# <div class="miniBar">
#     <div class="left">
#         <div class="topSocialBtn active">
#             <a href="https://www.facebook.com/marieclaire.tw" target="_blank"></a>
#             <a href="https://www.instagram.com/marieclairetw/" target="_blank"></a>
#             <a href="https://www.youtube.com/channel/UC10UnB0HM55-1Jjl2MpwijA?sub_confirmation=1" target="_blank"></a>
#             <a href="https://news.google.com/publications/CAAqBwgKMNH97wowkM_PAg?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant" target="_blank"></a>
#             <a href="https://www.marieclaire.com.tw/rss/google/search_news/all"></a>
#         </div>
#         <div class="logoBtn">
#             <button id="mobile_sider_menu"><div class="navLine"></div></button>
#             <a href="/"><img id="lazy_images" data-src="https://i.marieclaire.com.tw/assets/www/images/logo/logo.png" alt="Marie Claire 美麗佳人 - 流行時尚, 彩妝美容, 名人明星, 風格生活"/></a>
#         </div>
#     </div>
#     <a href="/"><img src="..."></a>
#     <div class="right">
#         <div class="tags" id="top_text_banner"></div>
#         <button class="searchBtn"></button>
#     </div>
#     <div class="searchBox" id="search_nav">
#         <input name="search_keyword" type="text" placeholder="請輸入搜尋關鍵字..." />
#         <button class="goSearch">GO!</button>
#     </div>
#     <div class="slideMenu" id="slide_menu"></div>
# </div>
# <div class="adSky dfp_imp" id="pc_lovesex_supersky" style="display:none;"></div>
# <div class="adSkin dfp_imp" id="pc_lovesex_skin" style="display:none;"></div>
# <section class="main">
#     <header>
#     <a href="https://www.marieclaire.com.tw/" title="Marie Claire 美麗佳人 - 流行時尚, 彩妝美容, 名人明星, 風格生活"><svg xmlns="http://www.w3.org/2000/svg" width="415" height="70"><image width="415" height="70" href="..."/></svg></a>
#     <div class="headerTags" id="top_text_banner"></div>
#     <nav>
#         <ul>
#             <li><button><div class="navLine"></div></button></li>
#                         <li>
#                 <a href="/fashion" id="pc_menu"><span>FASHION</span><div class="navArrows"></div></a>
#                 <div class="navDown" id="nav_fashion" data-category="fashion">
#                     <ul class="subMenu">
#     <li><a href="/fashion/news" title="時尚快報">時尚快報</a></li>
#     <li><a href="/fashion/snapshots" title="街拍直擊">街拍直擊</a></li>
#     <li><a href="/fashion/fashion-show" title="秀場直擊">秀場直擊</a></li>
#     <li><a href="/fashion/special" title="時尚企劃">時尚企劃</a></li>
#     <li><a href="/fashion/feature" title="風格專題">風格專題</a></li>
#                     </ul>
#                     <ul class="navDownList"></ul>
#                 </div>
#             </li>
#             <li>
#                 <a href="/luxury" id="pc_menu"><span>LUXURY</span><div class="navArrows"></div></a>
#                 <div class="navDown" id="nav_luxury" data-category="luxury">
#                     <ul class="subMenu">
#     <li><a href="/luxury/update" title="奢華快報">奢華快報</a></li>
#     <li><a href="/luxury/masters" title="行家帶路">行家帶路</a></li>
#     <li><a href="/luxury/try-on" title="奢華放大鏡">奢華放大鏡</a></li>
#                     </ul>
#                     <ul class="navDownList"></ul>
#                 </div>
#             </li>
#             <li>
#                 <a href="/beauty" id="pc_menu"><span>BEAUTY</span><div class="navArrows"></div></a>
#                 <div class="navDown" id="nav_beauty" data-category="beauty">
#                     <ul class="subMenu">
#     <li><a href="/beauty/news" title="美妝快遞">美妝快遞</a></li>
#     <li><a href="/beauty/make-up" title="美麗彩妝">美麗彩妝</a></li>
#     <li><a href="/beauty/hair" title="潮流髮型">潮流髮型</a></li>
#     <li><a href="/beauty/skin-care" title="美麗保養">美麗保養</a></li>
#     <li><a href="/beauty/health-fitness" title="美體健身">美體健身</a></li>
#     <li><a href="/video/astrology" title="星座運勢">星座運勢</a></li>
#     <li><a href="/video/stylelabs" title="玩美實驗室">玩美實驗室</a></li>
#                     </ul>
#                     <ul class="navDownList"></ul>
#                 </div>
#             </li>
#         </ul>
#     </nav>
# </header>    <main>
#     <section class="mcNews channel">
#     <h1>LOVE & SEX</h1>
#     <div class="subPages">
#         <ul>
#             <li class="active"><a href="/love-sex">VIEW ALL</a></li>
#             <li><a href="/love-sex/sex-relationship">愛情慾望</a></li>
#             <li><a href="/love-sex/astrology">星座運勢</a></li>
#             <li><a href="/love-sex/psychological">心理測驗</a></li>
#         </ul>
#     </div>
#     <div class="hotNews">
#         <div class="news">
#             <a href="https://www.marieclaire.com.tw/love-sex/sex-relationship/46647">
#                 <img id="lazy_images" src="https://im.marieclaire.com.tw/s552c310h100b100/assets/mc/201912/5DEF6F7CE05001575972732.jpeg" data-src="https://im.marieclaire.com.tw/s800c533h100b0/assets/mc/201912/5DEF6F7CE05001575972732.jpeg" alt="用運動達到真高潮！5種讓「愛愛」時更愉悅的「性愛體操」，還不趕緊練起來~" />
#                 <h4>LOVE & SEX 愛情慾望</h4>
#                 <h2>用運動達到真高潮！5種讓「愛愛」時更愉悅的「性愛體操」，還不趕緊練起來~</h2>
#                 <p>愛運動的身體不會變壞！想在愛愛時不小心壞掉掉，達到無比愉悅的狀態，一定要時常運動才能做到，不然只靠男伴搗樁，不一定靠得住阿~</p>
#                 <p class="date" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
#                                 by <a href="https://www.marieclaire.com.tw/author/72/派脆克"><span rel="author" itemprop="name">派脆克</span></a> -
#                                 <span data-publish-date="2019-12-10T18:09:47+00:00" data-format="YYYY/MM/DD">10 DEC 2019</span></p>
#             </a>
#         </div>
#         <div class="hot">
# <a href="https://www.marieclaire.com.tw/love-sex/astrology/46548" class="hotBox">
#     <img id="lazy_images" src="data:image/jpeg;base64,..." data-src="https://im.marieclaire.com.tw/s800c533h100b0/assets/mc/201912/5DE8B91D6F0F81575532829.jpeg" alt="《美麗佳人》2020年12星座運勢大預言！愛情運、工作運、健康運一次大揭密！（上）" />
#     <h4>LOVE & SEX 星座運勢</h4>
#     <h3>《美麗佳人》2020年12星座運勢大預言！愛情運、工作運、健康運一次大揭密！（上）</h3>
# </a>
# <a href="https://www.marieclaire.com.tw/love-sex/astrology/46551" class="hotBox">
#     <img id="lazy_images" src="data:image/jpeg;base64,..." data-src="https://im.marieclaire.com.tw/s800c533h100b0/assets/mc/201912/5DE8CA5A526311575537242.jpeg" alt="《美麗佳人》2020年12星座運勢大預言！愛情運、工作運、健康運一次大揭密！（下）" />
#     <h4>LOVE & SEX 星座運勢</h4>
#     <h3>《美麗佳人》2020年12星座運勢大預言！愛情運、工作運、健康運一次大揭密！（下）</h3>
# </a>
# <a href="https://www.marieclaire.com.tw/love-sex/astrology/46319" class="hotBox">
#     <img id="lazy_images" src="data:image/jpeg;base64,..." data-src="https://im.marieclaire.com.tw/s800c533h100b0/assets/mc/201911/5DDA49EDEC1541574586861.jpeg" alt="【星星教授安格斯2019/11/25-12/1星座運勢】獅子桃花運強、摩羯受長官提拔、雙魚婚期近了" />
#     <h4>LOVE & SEX 星座運勢</h4>
#     <h3>【星星教授安格斯2019/11/25-12/1星座運勢】獅子桃花運強、摩羯受長官提拔、雙魚婚期近了</h3>
# </a>
# <a href="https://www.marieclaire.com.tw/love-sex/astrology/46447" class="hotBox">
#     <img id="lazy_images" src="data:image/jpeg;base64,..." data-src="https://im.marieclaire.com.tw/s800c533h100b0/assets/mc/201911/5DE27ED6E46F61575124694.jpeg" alt="《美麗佳人》十二月星座運勢：「這個月吉多兇少，各星座多能心想事成！」" />
#     <h4>LOVE & SEX 星座運勢</h4>
#     <h3>《美麗佳人》十二月星座運勢：「這個月吉多兇少，各星座多能心想事成！」</h3>
# </a>
#         </div>
#     </div><!-- hot news end -->
# </section>
# <div id="channel_banner_1">
# </div>
# <div class="articleList" data-type="channel" data-category="love-sex" data-sub_category="">
#     <div class="articleBox">
#         <div class="left">
#             <a href="https://www.marieclaire.com.tw/love-sex/astrology/46639"><img id="lazy_images" src="data:image/jpeg;base64,..." data-src="https://im.marieclaire.com.tw/s800c533h100b0/assets/mc/201912/5
#         <li><a href="http://mc.marieclaire.com.tw/magazine/">雜誌訂閱</a></li>
#         <li><a href="/privacy">隱私權政策</a></li>
#         <li><a href="/about">關於我們</a></li>
#         <li><a href="/disclaimer">免責申明</a></li>
#         <li><a href="/ad/specs">廣告製作規範</a></li>
#     </ul>
#     <div class="footerSocialBtn">
#         <a href="https://www.facebook.com/marieclaire.tw"></a>
#         <a href="https://www.instagram.com/marieclairetw/"></a>
#         <a href="https://www.youtube.com/channel/UC10UnB0HM55-1Jjl2MpwijA?sub_confirmation=1"></a>
#         <a href="https://news.google.com/publications/CAAqBwgKMNH97wowkM_PAg?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant"></a>
#         <a href="https://www.marieclaire.com.tw/rss/google/search_news/all"></a>
#     </div>
#     <div class="copyright">&copy; 2019 Marie Claire All Rights Reserved.</div>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/lazyload@2.0.0-beta.2/lazyload.js"></script>
# <script async defer src="https://i.marieclaire.com.tw/assets/www/js/embed/1.4.63/public/mc.min.js"></script>
# </footer>
# <noscript><img src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=GLBoh1aMQV00y/" style="display:none" height="1" width="1" alt="" /></noscript>
# <noscript><img src="https://sb.scorecardresearch.com/p?c1=2&c2=14383407&cv=2.0&cj=1" /></noscript>
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-M5V6KWS"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#
# <script>
# var marieclaireinsight = marieclaireinsight || {};
#     marieclaireinsight.app_id = 100025531;
#     marieclaireinsight.ver = "1.0.3";
# </script>
# <script async defer src="https://i.mctw.com.tw/assets/insight/js/embed/1.0.3/insight.min.js"></script></body>
# </html>

# %%
soup = BeautifulSoup(resp.text, 'lxml')

# %%
hot = soup.find_all('div', class_='hot')

# %%
articles = hot[0].find_all('a')

# %%
articles
# Out:
# [<a class="hotBox" href="https://www.marieclaire.com.tw/love-sex/astrology/46548">
#  <img alt="《美麗佳人》2020年12星座運勢大預言！愛情運、工作運、健康運一次大揭密！（上）" data-src="https://im.marieclaire.com.tw/s800c533h100b0/assets/mc/201912/5DE8B91D6F0F81575532829.jpeg" id="lazy_images" src="data:image/jpeg;base64,..."/>
#  <h4>LOVE &amp; SEX 星座運勢</h4>
#  <h3>《美麗佳人》2020年12星座運勢大預言！愛情運、工作運、健康運一次大揭密！（上）</h3>
#  </a>,
#  <a class="hotBox" href="https://www.marieclaire.com.tw/love-sex/astrology/46551">
#  <img alt="《美麗佳人》2020年12星座運勢大預言！愛情運、工作運、健康運一次大揭密！（下）" data-src="https://im.marieclaire.com.tw/s800c533h100b0/assets/mc/201912/5DE8CA5A526311575537242.jpeg" id="lazy_images" src="data:image/jpeg;base64,..."/>
#  <h4>LOVE &amp; SEX 星座運勢</h4>
#  <h3>《美麗佳人》2020年12星座運勢大預言！愛情運、工作運、健康運一次大揭密！（下）</h3>
#  </a>,
#  <a class="hotBox" href="https://www.marieclaire.com.tw/love-sex/astrology/46319">
#  <img alt="【星星教授安格斯2019/11/25-12/1星座運勢】獅子桃花運強、摩羯受長官提拔、雙魚婚期近了" data-src="https://im.marieclaire.com.tw/s800c533h100b0/assets/mc/201911/5DDA49EDEC1541574586861.jpeg" id="lazy_images" src="data:image/jpeg;base64,..."/>
#  <h4>LOVE &amp; SEX 星座運勢</h4>
#  <h3>【星星教授安格斯2019/11/25-12/1星座運勢】獅子桃花運強、摩羯受長官提拔、雙魚婚期近了</h3>
#  </a>,
#  <a class="hotBox" href="https://www.marieclaire.com.tw/love-sex/astrology/46447">
#  <img alt="《美麗佳人》十二月星座運勢：「這個月吉多兇少，各星座多能心想事成！」" data-src="https://im.marieclaire.com.tw/s800c533h100b0/assets/mc/201911/5DE27ED6E46F61575124694.jpeg" id="lazy_images" src="data:image/jpeg;base64,..."/>
#  <h4>LOVE &amp; SEX 星座運勢</h4>
#  <h3>《美麗佳人》十二月星座運勢：「這個月吉多兇少，各星座多能心想事成！」</h3>
#  </a>]

# %%
len(articles)
# Out:
# 4

# %%
item = articles[2]

# %%
item.attrs
# Out:
# {'href': 'https://www.marieclaire.com.tw/love-sex/astrology/46319',
#  'class': ['hotBox']}

# %%
item['href']
# Out:
# 'https://www.marieclaire.com.tw/love-sex/astrology/46319'

# %%
title = item.find('h3')

# %%
title
# Out:
# <h3>【星星教授安格斯2019/11/25-12/1星座運勢】獅子桃花運強、摩羯受長官提拔、雙魚婚期近了</h3>
